# %% [markdown]
# # Generate the omega Test Plot
# ### Setup

# %%
from __future__ import division

import os

from pymongo import MongoClient
from pandas import DataFrame
from numpy import linspace

from cogent.maths.stats import chisqprob
from IPython.display import display, Image

# %%
# %load_ext rpy2.ipython
# %R library(ggplot2)
# Out:
# array(['ggplot2', 'tools', 'stats', 'graphics', 'grDevices', 'utils',
#        'datasets', 'methods', 'base'],
#       dtype='|S9')

# %%
try:
    os.mkdir('nt_style')
except OSError:
    pass

# %% [markdown]
# ### Utility

# %%
def get_ps(nul_col, alt_col):
    nul_fits = {d['_id'] : (d['lf']['ll'], d['lf']['df']) for d in nul_col.find()}
    alt_fits = {d['_id'] : (d['lf']['ll'], d['lf']['df']) for d in alt_col.find()}
    ps = []
    for _id in nul_fits:
        alt_ll, alt_df = alt_fits[_id]
        nul_ll, nul_df = nul_fits[_id]
        lr = 2.*(alt_ll - nul_ll)
        df = alt_df - nul_df
        ps.append(0. if lr < 0. else chisqprob(lr, df))
    ps = sorted(ps)
    print sum(1 for p in ps if p < 0.05)/len(ps)
    return ps

# %% [markdown]
# ### Load the Data

# %%
client = MongoClient()

# %%
print 'GNC'
ps = get_ps(client.mammals.GNC_clock, client.mammals.GNC)
ys = linspace(0., 1., len(ps)).tolist()
model = ['GNC']*len(ps)
print 'Y98'
ps += get_ps(client.mammals.Y98_same_omega_clock, client.mammals.Y98_same_omega)
ys += linspace(0., 1., len(ps) - len(model)).tolist()
model += ['Y98']*(len(ps) - len(model))
print 'CNFGTR'
ps += get_ps(client.mammals.CNFGTR_same_omega_clock, client.mammals.CNFGTR_same_omega)
ys += linspace(0., 1., len(ps) - len(model)).tolist()
model += ['CNFGTR']*(len(ps) - len(model))

df = DataFrame({'p':ps, 'y':ys, 'model':model})
print len(df)/3, 'points'
# Out:
# GNC
# 0.67686746988
# Y98
# 0.731325301205
# CNFGTR
# 0.726746987952
# 4150.0 points

# %% [markdown]
# ### Draw the Plot

# %%
# %%R -i df
# df$model <- factor(df$model, levels=c('GNC', 'CNFGTR', 'Y98'))
# gg <- ggplot(df, aes(p, y, linetype=model)) + geom_line() +
#     theme(legend.position = c(0.85, 0.15)) +
#     ylab('Empirical CDF') + ylim(c(0.4,1.0)) +
#     xlab('LRT P-value for Human/Mouse Molecular Clock')

# %%
name = os.path.join('nt_style', 'clock_test.png')
# %R -i name ggsave(name, gg, width=5, height=5)
display(Image(name))

# %%
sum(p == 0. for p in ps)/len(ps)
# Out:
# 0.013253012048192771
